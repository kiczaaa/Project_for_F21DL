# %%
# data processed below and stored

# %%
import kaggle
import os
import numpy as np
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
import sklearn
from zipfile import ZipFile
import cv2

# %%
# %store -r X_train
# %store -r X_cv
# %store -r y_train
# %store -r y_cv
# %store -r mmscaler
# %store -r pca
# %store -r X_train_pca
# %store -r X_train_scaled

# %%
# predict function 
def predict_data(classifier, scale=True, pca=True):
    if scale and pca:
        classifier.fit(X_train_pca, y_train)
        X_cv_scaled = mmscaler.transform(X_cv)
        X_cv_pca = pca.transform(X_cv_scaled)
        X_cv_pred = classifier.predict(X_cv_pca)
    elif scale:
        classifier.fit(X_train_scaled, y_train)
        X_cv_scaled = mmscaler.transform(X_cv)
        X_cv_pred = classifier.predict(X_cv_scaled)
    elif scale==False and pca==False:
        classifier.fit(X_train, y_train)
        X_cv_pred = classifier.predict(X_cv)
    return X_cv_pred

# %%
# make data from for evaluation metrics
columns = ['Accuracy', 'TP', 'FP', 'TN', 'FN', 'Sensitivity', 'Specificity', 'Precision', 'Recall', 'Area Under RoC Curve']
evaluation_metrics = pd.DataFrame(columns = columns)
evaluation_metrics
# Out:
# Empty DataFrame
# Columns: [Accuracy, TP, FP, TN, FN, Sensitivity, Specificity, Precision, Recall, Area Under RoC Curve]
# Index: []

# %%
from sklearn.metrics import confusion_matrix, precision_score, recall_score, roc_auc_score

# fill evaluation metrics table
def evaluate_classifier(dataframe, classifier, scale=True, pca=True):
    index = str(classifier)
    pred = predict_data(classifier, scale=scale, pca=pca)
    accuracy = sum(pred==y_cv)/len(y_cv)
    cm = confusion_matrix(y_cv, pred)
    tp, fp, tn, fn = cm[1,1], cm[0,1], cm[0,0], cm[1,0]
    sensitivity = tp / (tp+fn)
    specificity = tn / (tn+fp)
    precision = precision_score(y_cv, pred)
    recall = recall_score(y_cv, pred)
    auc = roc_auc_score(pred, y_cv)
    dataframe.loc[index] = [accuracy, tp, fp, tn, fn, sensitivity, specificity, precision, recall, auc]

# %%
from sklearn.naive_bayes import MultinomialNB, GaussianNB, ComplementNB, BernoulliNB, CategoricalNB
multinomialNB = MultinomialNB()
gaussianNB = GaussianNB()
complementNB = ComplementNB()
bernoulliNB = BernoulliNB()
categoricalNB = CategoricalNB()

# used normalized, but not feature extracted (not pca dimentionality reduction processed) data set 
# because most Naive Bayes classifiers do not accept negative values on training data
# also, Naive Bayes learners and classifiers can be extremely fast despite of high dimensions 

evaluate_classifier(evaluation_metrics, multinomialNB, pca=False)
evaluate_classifier(evaluation_metrics, gaussianNB, pca=False)
evaluate_classifier(evaluation_metrics, complementNB, pca=False)
evaluate_classifier(evaluation_metrics, bernoulliNB, pca=False)
evaluate_classifier(evaluation_metrics, categoricalNB, pca=False)
evaluation_metrics
# Out:
#                  Accuracy      TP     FP      TN      FN  Sensitivity  \
# MultinomialNB()  0.765123  1597.0  697.0  1856.0   363.0     0.814796
# GaussianNB()     0.669400  1333.0  865.0  1688.0   627.0     0.680102
# ComplementNB()   0.763572  1598.0  705.0  1848.0   362.0     0.815306
# BernoulliNB()    0.728784  1673.0  937.0  1616.0   287.0     0.853571
# CategoricalNB()  0.629958   855.0  565.0  1988.0  1105.0     0.436224
#
#                  Specificity  Precision    Recall  Area Under RoC Curve
# MultinomialNB()     0.726988   0.696164  0.814796              0.766288
# GaussianNB()        0.661183   0.606460  0.680102              0.667809
# ComplementNB()      0.723854   0.693878  0.815306              0.765038
# BernoulliNB()       0.632981   0.640996  0.853571              0.745091
# CategoricalNB()     0.778692   0.602113  0.436224              0.622427

# %% [markdown]
# ## Naive Bayes
# - Naive Bayes methods are a set of supervised learning algorithms based on applying Bayes' theorem with the 'naive' assumption of conditional independence between every pair of features given the value of the class variable.
# - The different naive Bayes classifiers differ mainly by the assumptions they make regarding the distribution of $P(x_i|y)$.
# - The decoupling of the class conditional feature distributions means that each distsribution can be independently estimated as a one dimensional distribution.
# - It is knwon to be good at claassification, but bad at estimation.

# %% [markdown]
# ### 1. MultinomialNB
# - Mutilnomail Naive Bayes classifier is suitable for classification with discrete features (e.g. word counts for text classification). The numltinomial distribution normally requiures integer feature counts. However, in practice, fractional counts such as tf-idf may also work.
#     - tf-idf, short for **term frequency-inverse document frequency**, is numerical statistic that is intended to relfect how important a word is to a document in a collection or corpus. Ofted used as a weighting factor in searches of information retrieval, text mining, and user modeling.
# - The parameters $\theta_y$ is estimated by a smoothed version of maximum likelihood, i.e. relative frequency counting:
#     - $\hat{\theta_{yi}} = $ $\large {{N_{yi} + \alpha} \over {N_y +  \alpha n}}$
#     - Setting $\alpha=1$ is called Laplace smoothing (Default), while $\alpha<1$ is called Lidstone smoothing.

# %% [markdown]
# #### Exploring Attributes and Methods

# %%
print("The number of samples encountered for each class during fitting: ", multinomialNB.class_count_)
print("The number of samples encountered for each class during fitting: ", sum(np.array(y_train)==0), sum(np.array(y_train)==1))
# Out:
# The number of samples encountered for each class during fitting:  [10012.  8039.]
# The number of samples encountered for each class during fitting:  10012 8039

# %%
import math
print("The Smoothed probability for each class: ", np.exp(multinomialNB.class_log_prior_))
print("The smoothed probability for each class: ", sum(np.array(y_train)==0)/len(y_train), sum(np.array(y_train)==1)/len(y_train))
# Out:
# The Smoothed probability for each class:  [0.55465071 0.44534929]
# The smoothed probability for each class:  0.5546507118719185 0.44534928812808156

# %%
print("The empirical log probability of features given a class, p(x_i|y): \n", multinomialNB.feature_log_prob_)
print("with shape: ", multinomialNB.feature_log_prob_.shape)
print("The probability of features given a class, p(x_i|y): \n",  np.exp(multinomialNB.feature_log_prob_))
print("with shape: ", np.exp(multinomialNB.feature_log_prob_).shape)
print("The sum of the probability of features given a class, p(x_i|y): \n",  np.exp(multinomialNB.feature_log_prob_).sum(axis=1))
# Out:
# The empirical log probability of features given a class, p(x_i|y):
#  [[-9.25276143 -9.28468328 -9.37842624 ... -9.2950064  -9.33821184
#   -9.44233523]
#  [-9.31141794 -9.32124067 -9.33223266 ... -9.32227054 -9.33741926
#   -9.35005999]]
# with shape:  (2, 12288)
# The probability of features given a class, p(x_i|y):
#  [[9.58466127e-05 9.28353303e-05 8.45281251e-05 ... 9.18819091e-05
#   8.79966480e-05 7.92950199e-05]
#  [9.03862915e-05 8.95027978e-05 8.85243718e-05 ... 8.94106691e-05
#   8.80664197e-05 8.69602022e-05]]
# with shape:  (2, 12288)
# The sum of the probability of features given a class, p(x_i|y):
#  [1. 1.]

# %%
print("Parameteres (default setting): ", multinomialNB.get_params())
# Out:
# Parameteres (default setting):  {'alpha': 1.0, 'class_prior': None, 'fit_prior': True}

# %% [markdown]
# #### Testing different alpha

# %%
columns = ['Accuracy', 'TP', 'FP', 'TN', 'FN', 'Sensitivity', 'Specificity', 'Precision', 'Recall', 'Area Under RoC Curve']
different_alphas = pd.DataFrame(columns = columns)
# from 0.1 to 1
alphas = np.linspace(0, 1, 11)
alphas = alphas[1:]
for alpha in alphas:
    multinomialNB = MultinomialNB(alpha=alpha)
    evaluate_classifier(different_alphas, multinomialNB, pca=False)
# from 1 to 10
alphas = np.linspace(1, 10, 10)
for alpha in alphas:
    multinomialNB = MultinomialNB(alpha=alpha)
    evaluate_classifier(different_alphas, multinomialNB, pca=False)
# from 10 to 100
alphas = np.linspace(10, 100, 10)
for alpha in alphas:
    multinomialNB = MultinomialNB(alpha=alpha)
    evaluate_classifier(different_alphas, multinomialNB, pca=False)
different_alphas
# Out:
#                                           Accuracy      TP     FP      TN  \
# MultinomialNB(alpha=0.1)                  0.764901  1597.0  698.0  1855.0
# MultinomialNB(alpha=0.2)                  0.764901  1597.0  698.0  1855.0
# MultinomialNB(alpha=0.30000000000000004)  0.764901  1597.0  698.0  1855.0
# MultinomialNB(alpha=0.4)                  0.764901  1597.0  698.0  1855.0
# MultinomialNB(alpha=0.5)                  0.765123  1597.0  697.0  1856.0
# MultinomialNB(alpha=0.6000000000000001)   0.765123  1597.0  697.0  1856.0
# MultinomialNB(alpha=0.7000000000000001)   0.765123  1597.0  697.0  1856.0
# MultinomialNB(alpha=0.8)                  0.765123  1597.0  697.0  1856.0
# MultinomialNB(alpha=0.9)                  0.765123  1597.0  697.0  1856.0
# MultinomialNB()                           0.765123  1597.0  697.0  1856.0
# MultinomialNB(alpha=2.0)                  0.765123  1597.0  697.0  1856.0
# MultinomialNB(alpha=3.0)                  0.765123  1597.0  697.0  1856.0
# MultinomialNB(alpha=4.0)                  0.765123  1597.0  697.0  1856.0
# MultinomialNB(alpha=5.0)                  0.765123  1597.0  697.0  1856.0
# MultinomialNB(alpha=6.0)                  0.765123  1597.0  697.0  1856.0
# MultinomialNB(alpha=7.0)                  0.765123  1597.0  697.0  1856.0
# MultinomialNB(alpha=8.0)                  0.765123  1597.0  697.0  1856.0
# MultinomialNB(alpha=9.0)                  0.764901  1596.0  697.0  1856.0
# MultinomialNB(alpha=10.0)                 0.764901  1596.0  697.0  1856.0
# MultinomialNB(alpha=20.0)                 0.764901  1594.0  695.0  1858.0
# MultinomialNB(alpha=30.0)                 0.765345  1592.0  691.0  1862.0
# MultinomialNB(alpha=40.0)                 0.765123  1590.0  690.0  1863.0
# MultinomialNB(alpha=50.0)                 0.765566  1590.0  688.0  1865.0
# MultinomialNB(alpha=60.0)                 0.765788  1588.0  685.0  1868.0
# MultinomialNB(alpha=70.0)                 0.766009  1586.0  682.0  1871.0
# MultinomialNB(alpha=80.0)                 0.766231  1586.0  681.0  1872.0
# MultinomialNB(alpha=90.0)                 0.766009  1585.0  681.0  1872.0
# MultinomialNB(alpha=100.0)                0.766009  1584.0  680.0  1873.0
#
#                                              FN  Sensitivity  Specificity  \
# MultinomialNB(alpha=0.1)                  363.0     0.814796     0.726596
# MultinomialNB(alpha=0.2)                  363.0     0.814796     0.726596
# MultinomialNB(alpha=0.30000000000000004)  363.0     0.814796     0.726596
# MultinomialNB(alpha=0.4)                  363.0     0.814796     0.726596
# MultinomialNB(alpha=0.5)                  363.0     0.814796     0.726988
# MultinomialNB(alpha=0.6000000000000001)   363.0     0.814796     0.726988
# MultinomialNB(alpha=0.7000000000000001)   363.0     0.814796     0.726988
# MultinomialNB(alpha=0.8)                  363.0     0.814796     0.726988
# MultinomialNB(alpha=0.9)                  363.0     0.814796     0.726988
# MultinomialNB()                           363.0     0.814796     0.726988
# MultinomialNB(alpha=2.0)                  363.0     0.814796     0.726988
# MultinomialNB(alpha=3.0)                  363.0     0.814796     0.726988
# MultinomialNB(alpha=4.0)                  363.0     0.814796     0.726988
# MultinomialNB(alpha=5.0)                  363.0     0.814796     0.726988
# MultinomialNB(alpha=6.0)                  363.0     0.814796     0.726988
# MultinomialNB(alpha=7.0)                  363.0     0.814796     0.726988
# MultinomialNB(alpha=8.0)                  363.0     0.814796     0.726988
# MultinomialNB(alpha=9.0)                  364.0     0.814286     0.726988
# MultinomialNB(alpha=10.0)                 364.0     0.814286     0.726988
# MultinomialNB(alpha=20.0)                 366.0     0.813265     0.727771
# MultinomialNB(alpha=30.0)                 368.0     0.812245     0.729338
# MultinomialNB(alpha=40.0)                 370.0     0.811224     0.729730
# MultinomialNB(alpha=50.0)                 370.0     0.811224     0.730513
# MultinomialNB(alpha=60.0)                 372.0     0.810204     0.731688
# MultinomialNB(alpha=70.0)                 374.0     0.809184     0.732863
# MultinomialNB(alpha=80.0)                 374.0     0.809184     0.733255
# MultinomialNB(alpha=90.0)                 375.0     0.808673     0.733255
# MultinomialNB(alpha=100.0)                376.0     0.808163     0.733647
#
#                                           Precision    Recall  \
# MultinomialNB(alpha=0.1)                   0.695861  0.814796
# MultinomialNB(alpha=0.2)                   0.695861  0.814796
# MultinomialNB(alpha=0.30000000000000004)   0.695861  0.814796
# MultinomialNB(alpha=0.4)                   0.695861  0.814796
# MultinomialNB(alpha=0.5)                   0.696164  0.814796
# MultinomialNB(alpha=0.6000000000000001)    0.696164  0.814796
# MultinomialNB(alpha=0.7000000000000001)    0.696164  0.814796
# MultinomialNB(alpha=0.8)                   0.696164  0.814796
# MultinomialNB(alpha=0.9)                   0.696164  0.814796
# MultinomialNB()                            0.696164  0.814796
# MultinomialNB(alpha=2.0)                   0.696164  0.814796
# MultinomialNB(alpha=3.0)                   0.696164  0.814796
# MultinomialNB(alpha=4.0)                   0.696164  0.814796
# MultinomialNB(alpha=5.0)                   0.696164  0.814796
# MultinomialNB(alpha=6.0)                   0.696164  0.814796
# MultinomialNB(alpha=7.0)                   0.696164  0.814796
# MultinomialNB(alpha=8.0)                   0.696164  0.814796
# MultinomialNB(alpha=9.0)                   0.696031  0.814286
# MultinomialNB(alpha=10.0)                  0.696031  0.814286
# MultinomialNB(alpha=20.0)                  0.696374  0.813265
# MultinomialNB(alpha=30.0)                  0.697328  0.812245
# MultinomialNB(alpha=40.0)                  0.697368  0.811224
# MultinomialNB(alpha=50.0)                  0.697981  0.811224
# MultinomialNB(alpha=60.0)                  0.698636  0.810204
# MultinomialNB(alpha=70.0)                  0.699295  0.809184
# MultinomialNB(alpha=80.0)                  0.699603  0.809184
# MultinomialNB(alpha=90.0)                  0.699470  0.808673
# MultinomialNB(alpha=100.0)                 0.699647  0.808163
#
#                                           Area Under RoC Curve
# MultinomialNB(alpha=0.1)                              0.766100
# MultinomialNB(alpha=0.2)                              0.766100
# MultinomialNB(alpha=0.30000000000000004)              0.766100
# MultinomialNB(alpha=0.4)                              0.766100
# MultinomialNB(alpha=0.5)                              0.766288
# MultinomialNB(alpha=0.6000000000000001)               0.766288
# MultinomialNB(alpha=0.7000000000000001)               0.766288
# MultinomialNB(alpha=0.8)                              0.766288
# MultinomialNB(alpha=0.9)                              0.766288
# MultinomialNB()                                       0.766288
# MultinomialNB(alpha=2.0)                              0.766288
# MultinomialNB(alpha=3.0)                              0.766288
# MultinomialNB(alpha=4.0)                              0.766288
# MultinomialNB(alpha=5.0)                              0.766288
# MultinomialNB(alpha=6.0)                              0.766288
# MultinomialNB(alpha=7.0)                              0.766288
# MultinomialNB(alpha=8.0)                              0.766288
# MultinomialNB(alpha=9.0)                              0.766034
# MultinomialNB(alpha=10.0)                             0.766034
# MultinomialNB(alpha=20.0)                             0.765903
# MultinomialNB(alpha=30.0)                             0.766153
# MultinomialNB(alpha=40.0)                             0.765836
# MultinomialNB(alpha=50.0)                             0.766216
# MultinomialNB(alpha=60.0)                             0.766282
# MultinomialNB(alpha=70.0)                             0.766351
# MultinomialNB(alpha=80.0)                             0.766542
# MultinomialNB(alpha=90.0)                             0.766291
# MultinomialNB(alpha=100.0)                            0.766231

# %% [markdown]
# ### 2. GausianNB
# - The likelihood of the features is assumed to be Gaussian: $P(x_i|y) =$ $1 \over \sqrt{2 \pi \sigma_y^2}$ $exp\Big(-$ ${(x_i - \mu_y)^2} \over 2\sigma_y^2 $ $\Big)$
#     - The parameter $\sigma_y$ and $\mu_y$ are estimated using maximum likelihood

# %% [markdown]
# #### Exploring Attributes and Methods

# %%
print("The number of samples encountered for each class during fitting: ", gaussianNB.class_count_)
print("The number of samples encountered for each class during fitting: ", sum(np.array(y_train)==0), sum(np.array(y_train)==1))
# Out:
# The number of samples encountered for each class during fitting:  [10012.  8039.]
# The number of samples encountered for each class during fitting:  10012 8039

# %%
import math
print("The Smoothed probability for each class: ", gaussianNB.class_prior_)
print("The smoothed probability for each class: ", sum(np.array(y_train)==0)/len(y_train), sum(np.array(y_train)==1)/len(y_train))
# Out:
# The Smoothed probability for each class:  [0.55465071 0.44534929]
# The smoothed probability for each class:  0.5546507118719185 0.44534928812808156

# %%
print("Mean of each feature per class: ", gaussianNB.theta_)
print("Check if theta_ same as mean(): ")
print(all(gaussianNB.theta_[0] == X_train_scaled[np.array(y_train)==0].mean(axis=0)))
print(all(gaussianNB.theta_[1] == X_train_scaled[np.array(y_train)==1].mean(axis=0)))
# Out:
# Mean of each feature per class:  [[0.67283495 0.65169287 0.59336835 ... 0.64499894 0.6177207  0.55662695]
#  [0.78620207 0.77851601 0.77000407 ... 0.77771452 0.76602006 0.75639639]]
# Check if theta_ same as mean():
# True
# True

# %%
print("Variance of each feature per class: ", gaussianNB.var_)
print("Check if var_ same as var(): ")
print(all(gaussianNB.var_[0] == X_train_scaled[np.array(y_train)==0].var(axis=0)))
print(all(gaussianNB.var_[1] == X_train_scaled[np.array(y_train)==1].var(axis=0)))
print("Check if two arrays are element-wise equal within epsilon_ tolerance: ")
print(np.allclose(gaussianNB.var_[0], X_train_scaled[np.array(y_train)==0].var(axis=0), atol=gaussianNB.epsilon_))
print(np.allclose(gaussianNB.var_[1], X_train_scaled[np.array(y_train)==1].var(axis=0), atol=gaussianNB.epsilon_))
# Out:
# Variance of each feature per class:  [[0.10666819 0.10874434 0.13554036 ... 0.1096265  0.11297788 0.13918359]
#  [0.09416442 0.09513553 0.10221959 ... 0.09533106 0.0985865  0.1055053 ]]
# Check if var_ same as var():
# False
# False
# Check if two arrays are element-wise equal within epsilon_ tolerance:
# True
# True

# %% [markdown]
# ### 3. ComplementNB
# - It is an adaptation of the standard multinomial naive Bayes algorithm that is particularly suited for imbalanced data sets.
# - It was designed to correct the "severe assumptions" made by the standard multinomial naive Bayes classifier.

# %%
complementNB.feature_count_
# Out:
# array([[6736.42352941, 6524.74901961, 5940.80392157, ..., 6457.72941176,
#         6184.61960784, 5572.94901961],
#        [6320.27843137, 6258.49019608, 6190.0627451 , ..., 6252.04705882,
#         6158.03529412, 6080.67058824]])

# %% [markdown]
# ### 4. BernoulliNB
# - It implements the naive Bayes training and classification algorithms for data that is distributed according to multivariate Bernoulli distributions **(each feature is assumed to be a binary-valued variable)**.
# - If any kind of data other than binary-value is provided, the `BernoulliNB` instance binarize its input (depending on `binarize` parameter).
# - This might perform better on some datasets, especially those with shorter documents.

# %%
bernoulliNB.feature_count_
# Out:
# array([[9896., 9888., 9809., ..., 9890., 9882., 9804.],
#        [7886., 7896., 7892., ..., 7892., 7898., 7901.]])

# %% [markdown]
# ### 5. Categorical Naive Bayes
# - It implements the categorical naive Bayes algorithm for categorically distributed data.
# - It assumes that each feature has its own categorical distribution.
# - It assumes that the sample matrix $X$ is encoded such that all categories for each feature $i$ are represented with numbers $0, \cdots, n_i-1$ where $n_i$ is the number of available categories of feature $i$.

# %%
print("The number of categories for each feature is all 2: ", all(categoricalNB.n_categories_==2))
# Out:
# The number of categories for each feature is all 2:  True

# %% [markdown]
# ### Compare to using non-scaled dataset

# %%
# evaluation metrics for non-scaled data
columns = ['Accuracy', 'TP', 'FP', 'TN', 'FN', 'Sensitivity', 'Specificity', 'Precision', 'Recall', 'Area Under RoC Curve']
evaluation_metrics_nn = pd.DataFrame(columns = columns)
evaluation_metrics_nn
# Out:
# Empty DataFrame
# Columns: [Accuracy, TP, FP, TN, FN, Sensitivity, Specificity, Precision, Recall, Area Under RoC Curve]
# Index: []

# %%
from sklearn.naive_bayes import MultinomialNB, GaussianNB, ComplementNB, BernoulliNB, CategoricalNB
multinomialNB = MultinomialNB()
gaussianNB = GaussianNB()
complementNB = ComplementNB()
bernoulliNB = BernoulliNB()
categoricalNB = CategoricalNB()

# used normalized, but not feature extracted (not pca dimentionality reduction processed) data set 
# because most Naive Bayes classifiers do not accept negative values on training data
# also, Naive Bayes learners and classifiers can be extremely fast despite of high dimensions 

evaluate_classifier(evaluation_metrics_nn, multinomialNB, scale=False, pca=False)
evaluate_classifier(evaluation_metrics_nn, gaussianNB, scale=False, pca=False)
evaluate_classifier(evaluation_metrics_nn, complementNB, scale=False, pca=False)
evaluate_classifier(evaluation_metrics_nn, bernoulliNB, scale=False, pca=False)
evaluate_classifier(evaluation_metrics_nn, categoricalNB, scale=False, pca=False)
evaluation_metrics_nn
# Out:
#                  Accuracy      TP     FP      TN     FN  Sensitivity  \
# MultinomialNB()  0.763572  1598.0  705.0  1848.0  362.0     0.815306
# GaussianNB()     0.669400  1333.0  865.0  1688.0  627.0     0.680102
# ComplementNB()   0.763572  1598.0  705.0  1848.0  362.0     0.815306
# BernoulliNB()    0.728784  1673.0  937.0  1616.0  287.0     0.853571
# CategoricalNB()  0.677376  1245.0  741.0  1812.0  715.0     0.635204
#
#                  Specificity  Precision    Recall  Area Under RoC Curve
# MultinomialNB()     0.723854   0.693878  0.815306              0.765038
# GaussianNB()        0.661183   0.606460  0.680102              0.667809
# ComplementNB()      0.723854   0.693878  0.815306              0.765038
# BernoulliNB()       0.632981   0.640996  0.853571              0.745091
# CategoricalNB()     0.709753   0.626888  0.635204              0.671972

# %%
evaluation_metrics
# Out:
#                  Accuracy      TP     FP      TN      FN  Sensitivity  \
# MultinomialNB()  0.765123  1597.0  697.0  1856.0   363.0     0.814796
# GaussianNB()     0.669400  1333.0  865.0  1688.0   627.0     0.680102
# ComplementNB()   0.763572  1598.0  705.0  1848.0   362.0     0.815306
# BernoulliNB()    0.728784  1673.0  937.0  1616.0   287.0     0.853571
# CategoricalNB()  0.629958   855.0  565.0  1988.0  1105.0     0.436224
#
#                  Specificity  Precision    Recall  Area Under RoC Curve
# MultinomialNB()     0.726988   0.696164  0.814796              0.766288
# GaussianNB()        0.661183   0.606460  0.680102              0.667809
# ComplementNB()      0.723854   0.693878  0.815306              0.765038
# BernoulliNB()       0.632981   0.640996  0.853571              0.745091
# CategoricalNB()     0.778692   0.602113  0.436224              0.622427

# %% [markdown]
# - Because some Naive Bayes models assume input feature represent count of appearance, we tried to use integer values.
#     - The original data range from 0 to 255 discretely, and normalized data range from 0 to 1.
# - When comparing results between using original data and normalized data,
#     - GaussianNB, ComplementNB, BernoulliNB has same result
#     - MultinomailNB works slightly (0.1%) better in normalized data
#     - CategoricalNB works better (approximately 5%) in non-normalized data

# %% [markdown]
# ## Discussions

# %%
# Final evaluation table
def highlight_max(x):
    return ['font-weight: bold' if v==x.iloc[evaluation_metrics['Accuracy'].argmax()] else '' for v in x]
evaluation_metrics.style.apply(highlight_max)
# Out:
# <style type="text/css">
# #T_f020f_row0_col0, #T_f020f_row0_col1, #T_f020f_row0_col2, #T_f020f_row0_col3, #T_f020f_row0_col4, #T_f020f_row0_col5, #T_f020f_row0_col6, #T_f020f_row0_col7, #T_f020f_row0_col8, #T_f020f_row0_col9 {
#   font-weight: bold;
# }
# </style>
# <table id="T_f020f">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f020f_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_f020f_level0_col1" class="col_heading level0 col1" >TP</th>
#       <th id="T_f020f_level0_col2" class="col_heading level0 col2" >FP</th>
#       <th id="T_f020f_level0_col3" class="col_heading level0 col3" >TN</th>
#       <th id="T_f020f_level0_col4" class="col_heading level0 col4" >FN</th>
#       <th id="T_f020f_level0_col5" class="col_heading level0 col5" >Sensitivity</th>
#       <th id="T_f020f_level0_col6" class="col_heading level0 col6" >Specificity</th>
#       <th id="T_f020f_level0_col7" class="col_heading level0 col7" >Precision</th>
#       <th id="T_f020f_level0_col8" class="col_heading level0 col8" >Recall</th>
#       <th id="T_f020f_level0_col9" class="col_heading level0 col9" >Area Under RoC Curve</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f020f_level0_row0" class="row_heading level0 row0" >MultinomialNB()</th>
#       <td id="T_f020f_row0_col0" class="data row0 col0" >0.765123</td>
#       <td id="T_f020f_row0_col1" class="data row0 col1" >1597.000000</td>
#       <td id="T_f020f_row0_col2" class="data row0 col2" >697.000000</td>
#       <td id="T_f020f_row0_col3" class="data row0 col3" >1856.000000</td>
#       <td id="T_f020f_row0_col4" class="data row0 col4" >363.000000</td>
#       <td id="T_f020f_row0_col5" class="data row0 col5" >0.814796</td>
#       <td id="T_f020f_row0_col6" class="data row0 col6" >0.726988</td>
#       <td id="T_f020f_row0_col7" class="data row0 col7" >0.696164</td>
#       <td id="T_f020f_row0_col8" class="data row0 col8" >0.814796</td>
#       <td id="T_f020f_row0_col9" class="data row0 col9" >0.766288</td>
#     </tr>
#     <tr>
#       <th id="T_f020f_level0_row1" class="row_heading level0 row1" >GaussianNB()</th>
#       <td id="T_f020f_row1_col0" class="data row1 col0" >0.669400</td>
#       <td id="T_f020f_row1_col1" class="data row1 col1" >1333.000000</td>
#       <td id="T_f020f_row1_col2" class="data row1 col2" >865.000000</td>
#       <td id="T_f020f_row1_col3" class="data row1 col3" >1688.000000</td>
#       <td id="T_f020f_row1_col4" class="data row1 col4" >627.000000</td>
#       <td id="T_f020f_row1_col5" class="data row1 col5" >0.680102</td>
#       <td id="T_f020f_row1_col6" class="data row1 col6" >0.661183</td>
#       <td id="T_f020f_row1_col7" class="data row1 col7" >0.606460</td>
#       <td id="T_f020f_row1_col8" class="data row1 col8" >0.680102</td>
#       <td id="T_f020f_row1_col9" class="data row1 col9" >0.667809</td>
#     </tr>
#     <tr>
#       <th id="T_f020f_level0_row2" class="row_heading level0 row2" >ComplementNB()</th>
#       <td id="T_f020f_row2_col0" class="data row2 col0" >0.763572</td>
#       <td id="T_f020f_row2_col1" class="data row2 col1" >1598.000000</td>
#       <td id="T_f020f_row2_col2" class="data row2 col2" >705.000000</td>
#       <td id="T_f020f_row2_col3" class="data row2 col3" >1848.000000</td>
#       <td id="T_f020f_row2_col4" class="data row2 col4" >362.000000</td>
#       <td id="T_f020f_row2_col5" class="data row2 col5" >0.815306</td>
#       <td id="T_f020f_row2_col6" class="data row2 col6" >0.723854</td>
#       <td id="T_f020f_row2_col7" class="data row2 col7" >0.693878</td>
#       <td id="T_f020f_row2_col8" class="data row2 col8" >0.815306</td>
#       <td id="T_f020f_row2_col9" class="data row2 col9" >0.765038</td>
#     </tr>
#     <tr>
#       <th id="T_f020f_level0_row3" class="row_heading level0 row3" >BernoulliNB()</th>
#       <td id="T_f020f_row3_col0" class="data row3 col0" >0.728784</td>
#       <td id="T_f020f_row3_col1" class="data row3 col1" >1673.000000</td>
#       <td id="T_f020f_row3_col2" class="data row3 col2" >937.000000</td>
#       <td id="T_f020f_row3_col3" class="data row3 col3" >1616.000000</td>
#       <td id="T_f020f_row3_col4" class="data row3 col4" >287.000000</td>
#       <td id="T_f020f_row3_col5" class="data row3 col5" >0.853571</td>
#       <td id="T_f020f_row3_col6" class="data row3 col6" >0.632981</td>
#       <td id="T_f020f_row3_col7" class="data row3 col7" >0.640996</td>
#       <td id="T_f020f_row3_col8" class="data row3 col8" >0.853571</td>
#       <td id="T_f020f_row3_col9" class="data row3 col9" >0.745091</td>
#     </tr>
#     <tr>
#       <th id="T_f020f_level0_row4" class="row_heading level0 row4" >CategoricalNB()</th>
#       <td id="T_f020f_row4_col0" class="data row4 col0" >0.629958</td>
#       <td id="T_f020f_row4_col1" class="data row4 col1" >855.000000</td>
#       <td id="T_f020f_row4_col2" class="data row4 col2" >565.000000</td>
#       <td id="T_f020f_row4_col3" class="data row4 col3" >1988.000000</td>
#       <td id="T_f020f_row4_col4" class="data row4 col4" >1105.000000</td>
#       <td id="T_f020f_row4_col5" class="data row4 col5" >0.436224</td>
#       <td id="T_f020f_row4_col6" class="data row4 col6" >0.778692</td>
#       <td id="T_f020f_row4_col7" class="data row4 col7" >0.602113</td>
#       <td id="T_f020f_row4_col8" class="data row4 col8" >0.436224</td>
#       <td id="T_f020f_row4_col9" class="data row4 col9" >0.622427</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# - Why MultinomailNB works best?
#     - It is known to be good at text analysis, spam filtering, etc. Our data is originally image data and mapped into pixel data, where multiple columns represent whether shape exists in a specific location in the image or not. This representation cound be considered similar to the one used in spam filetring, where the existence of specific words decide the class.
# - Why GaussinNB and CategoricalNB show lower accuracy?
#     - Our pixel data range from 0 to 255, discretely.
#     - GaussianNB assumes that data is continuous, and CategoricalNB assumes that data is categorical. We guess the reason why these two classifier shows lower accuracy is that these assumes different data types from our data.
#     - This also explains why ComplementNB and BernoulliNB work quite well. ComplementNB is based on MultinomialNB and BernoulliNB see data as binary, which is enough to explain the shape and color (if RGB).

# %% [markdown]
# ## Bayes Nets
# Using `bnlearn` library

# %%
pip install bnlearn
# Out:
# Requirement already satisfied: bnlearn in c:\users\jhl\miniconda3\envs\f21dl\lib\site-packages (0.7.6)
# Requirement already satisfied: tabulate in c:\users\jhl\miniconda3\envs\f21dl\lib\site-packages (from bnlearn) (0.9.0)
# Requirement already satisfied: tqdm in c:\users\jhl\miniconda3\envs\f21dl\lib\site-packages (from bnlearn) (4.64.1)
# Requirement already satisfied: funcsigs in c:\users\jhl\miniconda3\envs\f21dl\lib\site-packages (from bnlearn) (1.0.2)
# Requirement already satisfied: community in c:\users\jhl\miniconda3\envs\f21dl\lib\site-packages (from bnlearn) (1.0.0b1)
# Requirement already satisfied: pyvis in c:\users\jhl\miniconda3\envs\f21dl\lib\site-packages (from bnlearn) (0.3.0)
# Requirement already satisfied: pgmpy>=0.1.13 in c:\users\jhl\miniconda3\envs\f21dl\lib\site-packages (from bnlearn) (0.1.20)
# Requirement already satisfied: df2onehot in c:\users\jhl\miniconda3\envs\f21dl\lib\site-packages (from bnlearn) (1.0.1)
# Requirement already satisfied: wget in c:\users\jhl\miniconda3\envs\f21dl\lib\site-packages (from bnlearn) (3.2)
# Requirement already satisfied: numpy in c:\users\jhl\miniconda3\envs\f21dl\lib\site-packages (from bnlearn) (1.23.2)
# Requirement already satisfied: fsspec in c:\users\jhl\miniconda3\envs\f21dl\lib\site-packages (from bnlearn) (2022.8.2)
# Requirement already satisfied: pypickle in c:\users\jhl\miniconda3\envs\f21dl\lib\site-packages (from bnlearn) (1.1.0)
# Requirement already satisfied: networkx>=2.7.1 in c:\users\jhl\miniconda3\envs\f21dl\lib\site-packages (from bnlearn) (2.8.7)
# Requirement already satisfied: ismember in c:\users\jhl\miniconda3\envs\f21dl\lib\site-packages (from bnlearn) (1.0.2)
# Requirement already satisfied: packaging in c:\users\jhl\miniconda3\envs\f21dl\lib\site-packages (from bnlearn) (21.3)
# Requirement already satisfied: sklearn in c:\users\jhl\miniconda3\envs\f21dl\lib\site-packages (from bnlearn) (0.0)
# Requirement already satisfied: ipywidgets in c:\users\jhl\miniconda3\envs\f21dl\lib\site-packages (from bnlearn) (8.0.2)
# Requirement already satisfied: matplotlib>=3.3.4 in c:\users\jhl\miniconda3\envs\f21dl\lib\site-packages (from bnlearn) (3.5.3)
# Requirement already satisfied: statsmodels in c:\users\jhl\miniconda3\envs\f21dl\lib\site-packages (from bnlearn) (0.13.2)
# Requirement already satisfied: pandas in c:\users\jhl\miniconda3\envs\f21dl\lib\site-packages (from bnlearn) (1.4.4)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\jhl\miniconda3\envs\f21dl\lib\site-packages (from matplotlib>=3.3.4->bnlearn) (3.0.9)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\jhl\miniconda3\envs\f21dl\lib\site-packages (from matplotlib>=3.3.4->bnlearn) (1.4.4)
# Requirement already satisfied: cycler>=0.10 in c:\users\jhl\miniconda3\envs\f21dl\lib\site-packages (from matplotlib>=3.3.4->bnlearn) (0.11.0)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\jhl\miniconda3\envs\f21dl\lib\site-packages (from matplotlib>=3.3.4->bnlearn) (9.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\jhl\miniconda3\envs\f21dl\lib\site-packages (from matplotlib>=3.3.4->bnlearn) (2.8.2)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\jhl\miniconda3\envs\f21dl\lib\site-packages (from matplotlib>=3.3.4->bnlearn) (4.37.1)
# Requirement already satisfied: joblib in c:\users\jhl\miniconda3\envs\f21dl\lib\site-packages (from pgmpy>=0.1.13->bnlearn) (1.1.0)
# Requirement already satisfied: scipy in c:\users\jhl\miniconda3\envs\f21dl\lib\site-packages (from pgmpy>=0.1.13->bnlearn) (1.9.1)
# Requirement already satisfied: torch in c:\users\jhl\miniconda3\envs\f21dl\lib\site-packages (from pgmpy>=0.1.13->bnlearn) (1.12.1)
# Requirement already satisfied: opt-einsum in c:\users\jhl\miniconda3\envs\f21dl\lib\site-packages (from pgmpy>=0.1.13->bnlearn) (3.3.0)
# Requirement already satisfied: scikit-learn in c:\users\jhl\miniconda3\envs\f21dl\lib\site-packages (from pgmpy>=0.1.13->bnlearn) (1.1.2)
# Requirement already satisfied: Flask in c:\users\jhl\miniconda3\envs\f21dl\lib\site-packages (from community->bnlearn) (2.2.2)
# Requirement already satisfied: requests in c:\users\jhl\miniconda3\envs\f21dl\lib\site-packages (from community->bnlearn) (2.28.1)
# Requirement already satisfied: jupyterlab-widgets~=3.0 in c:\users\jhl\miniconda3\envs\f21dl\lib\site-packages (from ipywidgets->bnlearn) (3.0.3)
# Requirement already satisfied: ipython>=6.1.0 in c:\users\jhl\miniconda3\envs\f21dl\lib\site-packages (from ipywidgets->bnlearn) (8.4.0)
# Requirement already satisfied: ipykernel>=4.5.1 in c:\users\jhl\miniconda3\envs\f21dl\lib\site-packages (from ipywidgets->bnlearn) (6.15.2)
# Requirement already satisfied: traitlets>=4.3.1 in c:\users\jhl\miniconda3\envs\f21dl\lib\site-packages (from ipywidgets->bnlearn) (5.3.0)
# Requirement already satisfied: widgetsnbextension~=4.0 in c:\users\jhl\miniconda3\envs\f21dl\lib\site-packages (from ipywidgets->bnlearn) (4.0.3)
# Requirement already satisfied: pytz>=2020.1 in c:\users\jhl\miniconda3\envs\f21dl\lib\site-packages (from pandas->bnlearn) (2022.2.1)
# Requirement already satisfied: jsonpickle>=1.4.1 in c:\users\jhl\miniconda3\envs\f21dl\lib\site-packages (from pyvis->bnlearn) (2.2.0)
# Requirement already satisfied: jinja2>=2.9.6 in c:\users\jhl\miniconda3\envs\f21dl\lib\site-packages (from pyvis->bnlearn) (3.1.2)
# Requirement already satisfied: patsy>=0.5.2 in c:\users\jhl\miniconda3\envs\f21dl\lib\site-packages (from statsmodels->bnlearn) (0.5.3)
# Requirement already satisfied: colorama in c:\users\jhl\miniconda3\envs\f21dl\lib\site-packages (from tqdm->bnlearn) (0.4.5)
# Requirement already satisfied: psutil in c:\users\jhl\miniconda3\envs\f21dl\lib\site-packages (from ipykernel>=4.5.1->ipywidgets->bnlearn) (5.9.0)
# Requirement already satisfied: tornado>=6.1 in c:\users\jhl\miniconda3\envs\f21dl\lib\site-packages (from ipykernel>=4.5.1->ipywidgets->bnlearn) (6.2)
# Requirement already satisfied: matplotlib-inline>=0.1 in c:\users\jhl\miniconda3\envs\f21dl\lib\site-packages (from ipykernel>=4.5.1->ipywidgets->bnlearn) (0.1.6)
# Requirement already satisfied: pyzmq>=17 in c:\users\jhl\miniconda3\envs\f21dl\lib\site-packages (from ipykernel>=4.5.1->ipywidgets->bnlearn) (23.2.0)
# Requirement already satisfied: jupyter-client>=6.1.12 in c:\users\jhl\miniconda3\envs\f21dl\lib\site-packages (from ipykernel>=4.5.1->ipywidgets->bnlearn) (7.3.5)
# Requirement already satisfied: debugpy>=1.0 in c:\users\jhl\miniconda3\envs\f21dl\lib\site-packages (from ipykernel>=4.5.1->ipywidgets->bnlearn) (1.5.1)
# Requirement already satisfied: nest-asyncio in c:\users\jhl\miniconda3\envs\f21dl\lib\site-packages (from ipykernel>=4.5.1->ipywidgets->bnlearn) (1.5.5)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\jhl\miniconda3\envs\f21dl\lib\site-packages (from ipython>=6.1.0->ipywidgets->bnlearn) (2.11.2)
# Requirement already satisfied: setuptools>=18.5 in c:\users\jhl\miniconda3\envs\f21dl\lib\site-packages (from ipython>=6.1.0->ipywidgets->bnlearn) (63.4.1)
# Requirement already satisfied: stack-data in c:\users\jhl\miniconda3\envs\f21dl\lib\site-packages (from ipython>=6.1.0->ipywidgets->bnlearn) (0.2.0)
# Requirement already satisfied: backcall in c:\users\jhl\miniconda3\envs\f21dl\lib\site-packages (from ipython>=6.1.0->ipywidgets->bnlearn) (0.2.0)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in c:\users\jhl\miniconda3\envs\f21dl\lib\site-packages (from ipython>=6.1.0->ipywidgets->bnlearn) (3.0.20)
# Requirement already satisfied: pickleshare in c:\users\jhl\miniconda3\envs\f21dl\lib\site-packages (from ipython>=6.1.0->ipywidgets->bnlearn) (0.7.5)
# Requirement already satisfied: decorator in c:\users\jhl\miniconda3\envs\f21dl\lib\site-packages (from ipython>=6.1.0->ipywidgets->bnlearn) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\jhl\miniconda3\envs\f21dl\lib\site-packages (from ipython>=6.1.0->ipywidgets->bnlearn) (0.18.1)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\jhl\miniconda3\envs\f21dl\lib\site-packages (from jinja2>=2.9.6->pyvis->bnlearn) (2.1.1)
# Requirement already satisfied: six in c:\users\jhl\miniconda3\envs\f21dl\lib\site-packages (from patsy>=0.5.2->statsmodels->bnlearn) (1.16.0)
# Requirement already satisfied: click>=8.0 in c:\users\jhl\miniconda3\envs\f21dl\lib\site-packages (from Flask->community->bnlearn) (8.1.3)
# Requirement already satisfied: Werkzeug>=2.2.2 in c:\users\jhl\miniconda3\envs\f21dl\lib\site-packages (from Flask->community->bnlearn) (2.2.2)
# Requirement already satisfied: itsdangerous>=2.0 in c:\users\jhl\miniconda3\envs\f21dl\lib\site-packages (from Flask->community->bnlearn) (2.1.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\jhl\miniconda3\envs\f21dl\lib\site-packages (from requests->community->bnlearn) (3.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\jhl\miniconda3\envs\f21dl\lib\site-packages (from requests->community->bnlearn) (2022.6.15)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\jhl\miniconda3\envs\f21dl\lib\site-packages (from requests->community->bnlearn) (1.26.12)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\jhl\miniconda3\envs\f21dl\lib\site-packages (from requests->community->bnlearn) (2.1.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\jhl\miniconda3\envs\f21dl\lib\site-packages (from scikit-learn->pgmpy>=0.1.13->bnlearn) (3.1.0)
# Requirement already satisfied: typing-extensions in c:\users\jhl\miniconda3\envs\f21dl\lib\site-packages (from torch->pgmpy>=0.1.13->bnlearn) (4.3.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\users\jhl\miniconda3\envs\f21dl\lib\site-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets->bnlearn) (0.8.3)
# Requirement already satisfied: entrypoints in c:\users\jhl\miniconda3\envs\f21dl\lib\site-packages (from jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets->bnlearn) (0.4)
# Requirement already satisfied: jupyter-core>=4.9.2 in c:\users\jhl\miniconda3\envs\f21dl\lib\site-packages (from jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets->bnlearn) (4.10.0)
# Requirement already satisfied: wcwidth in c:\users\jhl\miniconda3\envs\f21dl\lib\site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=6.1.0->ipywidgets->bnlearn) (0.2.5)
# Requirement already satisfied: pure-eval in c:\users\jhl\miniconda3\envs\f21dl\lib\site-packages (from stack-data->ipython>=6.1.0->ipywidgets->bnlearn) (0.2.2)
# Requirement already satisfied: executing in c:\users\jhl\miniconda3\envs\f21dl\lib\site-packages (from stack-data->ipython>=6.1.0->ipywidgets->bnlearn) (0.8.3)
# Requirement already satisfied: asttokens in c:\users\jhl\miniconda3\envs\f21dl\lib\site-packages (from stack-data->ipython>=6.1.0->ipywidgets->bnlearn) (2.0.5)
# Requirement already satisfied: pywin32>=1.0 in c:\users\jhl\miniconda3\envs\f21dl\lib\site-packages (from jupyter-core>=4.9.2->jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets->bnlearn) (302)
# Note: you may need to restart the kernel to use updated packages.

# %%
import bnlearn as bn
X_train_df = pd.DataFrame(X_train_scaled)
model = bn.structure_learning.fit(X_train_df)
G = bn.plot(model)
# Out:
# [bnlearn] >Computing best DAG using [hc]
# [bnlearn] >Set scoring type at [bic]

# %%
# %store model

# %% [markdown]
# ## Data preparation
# 1. process image to 64 * 64 * 3 (RGB) numeric data
# 2. train - cross validation split (0.8:0.2)
# 3. normalization (using min-max scaler)
# 4. feature extraction (using PCA)

# %%
import kaggle
import os
import numpy as np
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
import sklearn
from zipfile import ZipFile
import cv2

# %%
# !kaggle datasets download -d techsash/waste-classification-data
# Out:
# waste-classification-data.zip: Skipping, found more recently modified local copy (use --force to force download)

# %%
# unzip file (downloaded file located in the same folder as the notebook) 
zip_file_name = 'waste-classification-data'
with ZipFile(zip_file_name+'.zip', 'r') as files:
    files.extractall(zip_file_name)

# %%
# Process image
# get list of image file names 
train_image_dir = os.path.join('waste-classification-data', 'DATASET', 'TRAIN')
organic_train_dir = os.path.join(train_image_dir, 'O')
recyclable_train_dir = os.path.join(train_image_dir, 'R')
organic_train = os.listdir(organic_train_dir)
recyclable_train = os.listdir(recyclable_train_dir)
print("Number of organic (O) images in training set: ", len(organic_train))
print("Number of recyclable (R) images in training set: ", len(recyclable_train))

# convert list to pd.DataFrame 
file_names = []
file_names.extend(organic_train)
file_names.extend(recyclable_train)

# define function 
def get_fullpath(image_name):
    if image_name.startswith('O'):
        full_path = os.path.join(organic_train_dir, image_name)
    elif image_name.startswith('R'):
        full_path = os.path.join(recyclable_train_dir, image_name)
    return full_path

# use (64 * 64) as a new shape
new_shape = (64, 64)

images = []
# takes file_name with full path and desired shape as parameter
for file in file_names:
    full_path = get_fullpath(file)    
    image_wc = cv2.imread(full_path, cv2.IMREAD_COLOR)
    image_tc = cv2.cvtColor(src=image_wc, code=cv2.COLOR_BGR2RGB)
    # resize image 
    image_tc_rs = cv2.resize(src=image_tc, dsize=new_shape)
    # store image
    images.append(image_tc_rs)

# stack images to a single array
train_X = np.stack(images)
train_X = train_X.reshape(len(train_X), -1)
print("train_X: ", train_X.shape)
     
# define labels for images (0 for organic, 1 for recyclable)
train_y = [0] * len(organic_train)
train_y.extend([1] * len(recyclable_train))
# Out:
# Number of organic (O) images in training set:  12565
# Number of recyclable (R) images in training set:  9999
# train_X:  (22564, 12288)

# %%
# train-test (train-cross validatain) split
from sklearn.model_selection import train_test_split
X_train, X_cv, y_train, y_cv = train_test_split(train_X, train_y, test_size=0.2, random_state=42)

# %%
# min-man scale
from sklearn.preprocessing import MinMaxScaler
mmscaler = MinMaxScaler()
X_train_scaled = mmscaler.fit_transform(X_train)

# %%
# pca
from sklearn.decomposition import PCA
pca = PCA(n_components=0.95)
X_train_pca = pca.fit_transform(X_train_scaled)
print(X_train_pca.shape)
# Out:
# (18051, 1317)

# %%
# %store X_train
# %store X_cv
# %store y_train
# %store y_cv
# %store mmscaler
# %store pca
# %store X_train_scaled
# %store X_train_pca
# Out:
# Stored 'X_train' (ndarray)
# Stored 'X_cv' (ndarray)
# Stored 'y_train' (list)
# Stored 'y_cv' (list)
# Stored 'mmscaler' (MinMaxScaler)
# Stored 'pca' (PCA)
# Stored 'X_train_scaled' (ndarray)
# Stored 'X_train_pca' (ndarray)
